# %% [markdown]
# # Object-oriented neural network

# %%
from sklearn.datasets import make_moons
import numpy as np
import matplotlib.pyplot as plt
from utils.activations import ReLU, Sigmoid
from utils.losses import NLL
from model import NeuralNetwork

# %% [markdown]
# ### Generate dataset

# %%
X, Y = make_moons(noise=0.1)
Y = np.expand_dims(Y, 1)
plt.style.use('dark_background')
plt.scatter(X.T[0], X.T[1], c=Y, edgecolors='black')
plt.show()

# %% [markdown]
# ### Define model

# %%
model = NeuralNetwork([
    {'in_channels': X.shape[1], 'out_channels': 4, 'activation': ReLU()},
    {'in_channels': 4, 'out_channels': 4, 'activation': ReLU()},
    {'in_channels': 4, 'out_channels': Y.shape[1], 'activation': Sigmoid()}
], NLL())

# %% [markdown]
# ### Training

# %%
n_iterations = 2000
alpha = 0.1

model.train(X, Y, n_iterations, alpha)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/sw/g_nby91d5sv9k0l3dg_kwck00000gn/T/ipykernel_14234/672227026.py in <module>
#       2 alpha = 0.1
#       3
# ----> 4 model.train(X, Y, n_iterations, alpha)
#
# ~/code/object-oriented-NN/model.py in train(self, X, Y, n_iterations, alpha)
#      65
#      66         for epoch in range(n_iterations):
# ---> 67             gradients = self.backward(X, Y, cache)
#      68
#      69             for i in range(len(self.layers)):
#
# ~/code/object-oriented-NN/model.py in backward(self, X, Y, cache)
#      45                 dA = dZ_next @ W_next.T
#      46
# ---> 47             Z = self.cache[f'Z{i + 1}']
#      48             dZ = dA * layer['activation'].derivative(Z)
#      49
#
# AttributeError: 'NeuralNetwork' object has no attribute 'cache'

# %%
# !magick convert -delay 1 -loop 0 ./boundaries/full/*.png ./img/full/decision_boundary.gif
